# %% [markdown]
# ## **Версия датасета из углов для всех видео с АУГУМЕНТАЦИЕЙ.**

# %%
import gdown
import pandas as pd

# %%
PATH = '/content'

# %%
# Файл скачается у вас слева в /content/
url = 'https://drive.google.com/uc?export=download&id=1-06kdldMG4rVMevT6iW1iAtPiELEgxo2'
gdown.download(url, None)
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1-06kdldMG4rVMevT6iW1iAtPiELEgxo2
# To: /content/All_DataSet_Angles_v2_AUG.csv
# 100%|██████████| 99.7M/99.7M [00:00<00:00, 116MB/s]
# 'All_DataSet_Angles_v2_AUG.csv'

# %%
df_all = pd.read_csv(f'{PATH}/All_DataSet_Angles_v2_AUG.csv')

# %%
len(df_all)
# Out:
# 364256

# %%
df_all.head(len(df_all))
# df_all.head()
# Out:
#         class view belt  karateka  num  aug  frame  ang_0_(28)  ang_1_(27)  \
# 0           1    f   bb         1    1    0      0   66.172147  117.369039
# 1           1    f   bb         1    1    0      1   65.924200  113.887056
# 2           1    f   bb         1    1    0      2   63.160966  113.724980
# 3           1    f   bb         1    1    0      3   64.377065  116.079175
# 4           1    f   bb         1    1    0      4   62.420522  114.298452
# ...       ...  ...  ...       ...  ...  ...    ...         ...         ...
# 364251     10    p   wb         1   10    5     50  101.745740   76.737010
# 364252     10    p   wb         1   10    5     51   96.717382   69.527168
# 364253     10    p   wb         1   10    5     52   89.274522   73.707123
# 364254     10    p   wb         1   10    5     53   96.544949   76.560895
# 364255     10    p   wb         1   10    5     54   92.225178   74.761332
#
# ...

# %%
pd.set_option('display.max_rows', None)
temp_df = df_all[df_all["frame"] == 3]  # оставляем только кадр номер 3
temp_df[temp_df["class"] == 1]          # оставляем только class номер 1
temp_df[temp_df["num"] == 1]
# Out:
#         class view belt  karateka  num  aug  frame  ang_0_(28)  ang_1_(27)  \
# 3           1    f   bb         1    1    0      3   64.377065  116.079175
# 89          1    f   bb         1    1    1      3   64.377065  116.079175
# 175         1    f   bb         1    1    2      3   64.377065  116.079175
# 261         1    f   bb         1    1    3      3   64.377065  116.079175
# 347         1    f   bb         1    1    4      3   64.377065  116.079175
# 433         1    f   bb         1    1    5      3   64.377065  116.079175
# 3201        1    f   gb         1    1    0      3   69.962533  132.668376
# 3270        1    f   gb         1    1    1      3   69.962533  132.668376
# 3339        1    f   gb         1    1    2      3   69.962533  132.668376
# 3408        1    f   gb         1    1    3      3   69.962533  132.668376
# 3477        1    f   gb         1    1    4      3   69.962533  132.668376
# ...
